# %% [markdown]
# # Click Through Rate Estimation Using Empirical Bayes Method

# %% [markdown]
# ## Simulation

# %%
import pymc3 as pm

# %%
C0 = 100
N0 = 300
alpha = 20
beta = 80
with pm.Model() as model:
    obs = pm.BetaBinomial('obs', alpha, beta, N0)
    # probability = pm.Beta('prior', alpha, beta)
    # obs = pm.Binomial('observation', N0, probability, C0)

# %%
model
# Out:
# $$
#             \begin{array}{rcl}
#             \text{obs} &\sim & \text{BetaBinomial}(\mathit{alpha}=20.0,~\mathit{beta}=80.0)
#             \end{array}
#             $$

# %%
with model:
    trace = pm.sample(500)
# Out:
# Multiprocess sampling (4 chains in 4 jobs)
# Metropolis: [obs]
# Sampling 4 chains, 0 divergences: 100%|██████████| 4000/4000 [00:00<00:00, 7231.37draws/s]
# The number of effective samples is smaller than 25% for some parameters.

# %%
pm.traceplot(trace)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x12afda810>,
# ...
#       dtype=object)

# %%
pm.summary(trace)
# Out:
#        mean      sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_mean  ess_sd  \
# obs  60.693  13.321    35.0     83.0      0.746    0.539     319.0   306.0
#
#      ess_bulk  ess_tail  r_hat
# obs     328.0     318.0   1.03
