# %% [markdown]
# # Click Through Rate Estimation Using Empirical Bayes Method
# This is an example of using the empirical Bayesian shrinkage towards a Beta prior approach for Click Through Rate prediction.

# %% [markdown]
# ## Simulation

# %%
import pymc3 as pm

# %%
C0 = 100
N0 = 300
alpha = 81
beta = 219
with pm.Model() as model:
    obs = pm.BetaBinomial('obs', alpha, beta, N0)
    # probability = pm.Beta('prior', alpha, beta)
    # obs = pm.Binomial('observation', N0, probability, C0)

# %%
model
# Out:
# $$
#             \begin{array}{rcl}
#             \text{obs} &\sim & \text{BetaBinomial}(\mathit{alpha}=81.0,~\mathit{beta}=219.0)
#             \end{array}
#             $$

# %%
with model:
    trace = pm.sample(int(10000000/4))
# Out:
# Multiprocess sampling (4 chains in 4 jobs)
# Metropolis: [obs]
# Sampling 4 chains, 0 divergences: 100%|██████████| 10002000/10002000 [24:00<00:00, 6941.94draws/s]
# The number of effective samples is smaller than 25% for some parameters.

# %%
pm.traceplot(trace)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x12e6ea390>,
# ...
#       dtype=object)

# %%
observations = trace['obs']
len(observations[observations == 100])
# Out:
# 79529

# %%
len(trace['obs'])
# Out:
# 10000000
